# %%
# %env CUDA_VISIBLE_DEVICES = 5
# Out:
# env: CUDA_VISIBLE_DEVICES=5

# %%
from fetch_dataset_and_processing import find_train_val_files, find_test_files, ImageNet
from train_loop import train
from inference import predict, predict_one_sample, make_predictions
from visualizing import imshow, plot_train_set, plot_results

from resnet50 import IdentityBlock, ConvBlock, ResNet50
from resnet18_cnn import ResBlock, ResNet18

import torch
from sklearn.model_selection import train_test_split
import os
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
! nvidia-smi
# Out:
# Thu Feb  2 11:26:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.56.06    Driver Version: 520.56.06    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:1A:00.0 Off |                  N/A |
# | 26%   32C    P0    46W / 260W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:1B:00.0 Off |                  N/A |
# | 26%   31C    P0    46W / 260W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:1F:00.0 Off |                  N/A |
# | 27%   27C    P8    21W / 260W |   2349MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  Off  | 00000000:20:00.0 Off |                  N/A |
# | 27%   31C    P0    65W / 260W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA GeForce ...  Off  | 00000000:21:00.0 Off |                  N/A |
# | 26%   31C    P0    60W / 260W |      0MiB / 11264MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  NVIDIA GeForce ...  Off  | 00000000:22:00.0 Off |                  N/A |
# | 27%   25C    P8     1W / 260W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  NVIDIA GeForce ...  Off  | 00000000:23:00.0 Off |                  N/A |
# | 27%   28C    P8    24W / 260W |      3MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  NVIDIA GeForce ...  Off  | 00000000:24:00.0 Off |                  N/A |
# | 31%   31C    P0    54W / 260W |      0MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
device = 'cuda:0'

# %%
train_val_files, train_val_labels = find_train_val_files()
test_files, test_labels = find_test_files()

# %%
len(train_val_files), len(test_files)
# Out:
# (9103, 3791)

# %%
train_set, val_set, tr_labels, val_labels = train_test_split(train_val_files, train_val_labels, test_size=0.2, \
                                          stratify=train_val_labels)

# %%
train_dataset = ImageNet(train_set, tr_labels, 'train')
val_dataset = ImageNet(val_set, val_labels, 'val')
test_dataset = ImageNet(test_files, test_labels, 'test')

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# %% [markdown]
# ### ResNet 18

# %%
resnet = ResNet18(ResBlock).to(device)
resnet
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (linear): Linear(in_features=256, out_features=10, bias=True)
#   (layer1): Sequential(
#     (0): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Identity()
#     )
#     (1): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Identity()
#     )
#     (1): ResBlock(
#       (conv_block): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
# )

# %%
epochs = 10
opt = torch.optim.Adam(resnet.parameters(), lr=1e-4, weight_decay=1e-5)
loss_fn = nn.CrossEntropyLoss()
path = 'Resnet_with_reg.pth'
name = 'resnet_with_reg'

# %%
losses_res, metrics_res = train(resnet, opt, loss_fn, epochs, train_loader, val_loader, name, path)
# Out:
# Epoch 0/9:
# train iter:: 100%|██████████| 456/456 [00:50<00:00,  9.10it/s]
# train Loss: 1.6710
# train Accuracy: 0.4242
# val iter:: 100%|██████████| 114/114 [00:08<00:00, 14.24it/s]
# val Loss: 1.5370
# val Accuracy: 0.4990
# Epoch 1/9:
# train iter:: 100%|██████████| 456/456 [00:43<00:00, 10.57it/s]
# train Loss: 1.2362
# train Accuracy: 0.5927
# val iter:: 100%|██████████| 114/114 [00:07<00:00, 16.08it/s]
# val Loss: 1.3417
# val Accuracy: 0.5684
# Epoch 2/9:
# train iter:: 100%|██████████| 456/456 [00:41<00:00, 10.89it/s]
# train Loss: 1.0086
# train Accuracy: 0.6698
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 17.47it/s]
# val Loss: 1.4692
# val Accuracy: 0.5605
# Epoch 3/9:
# train iter:: 100%|██████████| 456/456 [00:40<00:00, 11.19it/s]
# train Loss: 0.8336
# train Accuracy: 0.7325
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 17.94it/s]
# val Loss: 1.2835
# val Accuracy: 0.6160
# Epoch 4/9:
# train iter:: 100%|██████████| 456/456 [00:41<00:00, 10.92it/s]
# train Loss: 0.5697
# train Accuracy: 0.8336
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 18.22it/s]
# val Loss: 0.7292
# val Accuracy: 0.7563
# Epoch 5/9:
# train iter:: 100%|██████████| 456/456 [00:40<00:00, 11.18it/s]
# train Loss: 0.4683
# train Accuracy: 0.8742
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 17.08it/s]
# val Loss: 0.7093
# val Accuracy: 0.7600
# Epoch 6/9:
# train iter:: 100%|██████████| 456/456 [00:43<00:00, 10.54it/s]
# train Loss: 0.3963
# train Accuracy: 0.9030
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 16.60it/s]
# val Loss: 0.7024
# val Accuracy: 0.7684
# Epoch 7/9:
# train iter:: 100%|██████████| 456/456 [00:42<00:00, 10.78it/s]
# train Loss: 0.3245
# train Accuracy: 0.9313
# val iter:: 100%|██████████| 114/114 [00:07<00:00, 15.40it/s]
# val Loss: 0.7040
# val Accuracy: 0.7711
# Epoch 8/9:
# train iter:: 100%|██████████| 456/456 [00:41<00:00, 11.06it/s]
# train Loss: 0.2608
# train Accuracy: 0.9537
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 17.78it/s]
# val Loss: 0.6891
# val Accuracy: 0.7766
# Epoch 9/9:
# train iter:: 100%|██████████| 456/456 [00:41<00:00, 11.02it/s]
# train Loss: 0.2452
# train Accuracy: 0.9598
# val iter:: 100%|██████████| 114/114 [00:06<00:00, 16.82it/s]
# val Loss: 0.6914
# val Accuracy: 0.7750

# %%
plt.plot(losses_res['train'], label='train')
plt.plot(losses_res['val'], label='val')
plt.legend()
plt.show()

# %%
plt.plot(metrics_res['train'], label='train')
plt.plot(metrics_res['val'], label='val')
plt.legend()
plt.show()

# %% [markdown]
# ### Inference

# %%
predictions_resnet = make_predictions(resnet, imgs_test)

# %%
accuracy_score(predictions_resnet, actual_labels_test)
# Out:
# 0.7728831442891058

# %%
plot_results(resnet, test_dataset)
